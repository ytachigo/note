# %%
import pandas as pd

# %%
df_amino = pd.read_table('amino.dat', delim_whitespace=True, skiprows=1, 
                         names=['Fullname', '3-letter', '1-letter'])

# %%
df_amino
# Out:
#          Fullname 3-letter 1-letter
# 0         Alanine      Ala        A
# 1        Arginine      Arg        R
# 2      Asparagine      Asn        N
# 3    AsparticAcid      Asp        D
# 4        Cysteine      Cys        C
# 5       Glutamine      Gln        Q
# 6    GlutamicAcid      Glu        E
# 7         Glycine      Gly        G
# 8       Histidine      His        H
# 9      Isoleucine      Ile        I
# 10        Leucine      Leu        L
# 11         Lysine      Lys        K
# 12     Methionine      Met        M
# 13  Phenylalanine      Phe        F
# 14        Proline      Pro        P
# 15         Serine      Ser        S
# 16      Threonine      Thr        T
# 17     Tryptophan      Trp        W
# 18       Tyrosine      Tyr        Y
# 19         Valine      Val        V
